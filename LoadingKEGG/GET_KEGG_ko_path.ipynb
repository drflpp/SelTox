# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno

np.random.seed(0)


from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_regression
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, r2_score
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_first = pd.read_csv('/content/drive/MyDrive/AgNPs/genes stuff/bacterial_gene_name_presence_absence (1).csv', index_col=0)

# %%
data_first
# Out:
#                                               CysP  \
# Klebsiella pneumoniae nan                        0
# Actinomyces naeslundii nan                       0
# Hafnia alvei nan                                 0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)     0
# Streptococcus mutans MTCC 497                    0
# ...                                            ...
# Aspergillus flavus FCBP-0064                     0
# Pseudomonas aeruginosa MTCC 424                  0
# Escherichia coli nan                             0
# Sphingomonas paucimobilis nan                    0
# Staphylococcus haemolyticus nan                  0
#
#                                               dTDP-4-dehydrorhamnose reductase  \
# Klebsiella pneumoniae nan                                                    0
# Actinomyces naeslundii nan                                                   0
# Hafnia alvei nan                                                             0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                 0
# Streptococcus mutans MTCC 497                                                0
# ...                                                                        ...
# Aspergillus flavus FCBP-0064                                                 0
# Pseudomonas aeruginosa MTCC 424                                              1
# Escherichia coli nan                                                         0
# Sphingomonas paucimobilis nan                                                0
# Staphylococcus haemolyticus nan                                              0
#
#                                               Flagellar protein FlgP  \
# Klebsiella pneumoniae nan                                          0
# Actinomyces naeslundii nan                                         0
# Hafnia alvei nan                                                   0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                       0
# Streptococcus mutans MTCC 497                                      0
# ...                                                              ...
# Aspergillus flavus FCBP-0064                                       0
# Pseudomonas aeruginosa MTCC 424                                    0
# Escherichia coli nan                                               0
# Sphingomonas paucimobilis nan                                      0
# Staphylococcus haemolyticus nan                                    0
#
#                                               Mac1 transcriptional regulator  \
# Klebsiella pneumoniae nan                                                  0
# Actinomyces naeslundii nan                                                 0
# Hafnia alvei nan                                                           0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                               0
# Streptococcus mutans MTCC 497                                              0
# ...                                                                      ...
# Aspergillus flavus FCBP-0064                                               0
# Pseudomonas aeruginosa MTCC 424                                            0
# Escherichia coli nan                                                       0
# Sphingomonas paucimobilis nan                                              0
# Staphylococcus haemolyticus nan                                            0
#
#                                               nuclear movement protein nudC  \
# Klebsiella pneumoniae nan                                                 0
# Actinomyces naeslundii nan                                                0
# Hafnia alvei nan                                                          0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                              0
# Streptococcus mutans MTCC 497                                             0
# ...                                                                     ...
# Aspergillus flavus FCBP-0064                                              0
# Pseudomonas aeruginosa MTCC 424                                           0
# Escherichia coli nan                                                      0
# Sphingomonas paucimobilis nan                                             0
# Staphylococcus haemolyticus nan                                           0
#
#                                               Defective in cullin neddylation protein 1  \
# Klebsiella pneumoniae nan                                                             0
# Actinomyces naeslundii nan                                                            0
# Hafnia alvei nan                                                                      0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                          0
# Streptococcus mutans MTCC 497                                                         0
# ...                                                                                 ...
# Aspergillus flavus FCBP-0064                                                          0
# Pseudomonas aeruginosa MTCC 424                                                       0
# Escherichia coli nan                                                                  0
# Sphingomonas paucimobilis nan                                                         0
# Staphylococcus haemolyticus nan                                                       0
#
#                                               ATP-dependent Clp protease proteolytic subunit (EC 3.4.21.92)  \
# Klebsiella pneumoniae nan                                                                     0
# Actinomyces naeslundii nan                                                                    0
# Hafnia alvei nan                                                                              0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                                  0
# Streptococcus mutans MTCC 497                                                                 0
# ...                                                                                         ...
# Aspergillus flavus FCBP-0064                                                                  0
# Pseudomonas aeruginosa MTCC 424                                                               0
# Escherichia coli nan                                                                          0
# Sphingomonas paucimobilis nan                                                                 0
# Staphylococcus haemolyticus nan                                                               0
#
#                                               UGO1  \
# Klebsiella pneumoniae nan                        0
# Actinomyces naeslundii nan                       0
# Hafnia alvei nan                                 0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)     0
# Streptococcus mutans MTCC 497                    0
# ...                                            ...
# Aspergillus flavus FCBP-0064                     0
# Pseudomonas aeruginosa MTCC 424                  0
# Escherichia coli nan                             0
# Sphingomonas paucimobilis nan                    0
# Staphylococcus haemolyticus nan                  0
#
#                                               pumilio-family RNA binding domain-containing protein  \
# Klebsiella pneumoniae nan                                                                     0
# Actinomyces naeslundii nan                                                                    0
# Hafnia alvei nan                                                                              0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                                  0
# Streptococcus mutans MTCC 497                                                                 0
# ...                                                                                         ...
# Aspergillus flavus FCBP-0064                                                                  0
# Pseudomonas aeruginosa MTCC 424                                                               0
# Escherichia coli nan                                                                          0
# Sphingomonas paucimobilis nan                                                                 0
# Staphylococcus haemolyticus nan                                                               0
#
#                                               oligopeptide transport system permease protein  \
# Klebsiella pneumoniae nan                                                                  0
# Actinomyces naeslundii nan                                                                 0
# Hafnia alvei nan                                                                           0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                               0
# Streptococcus mutans MTCC 497                                                              0
# ...                                                                                      ...
# Aspergillus flavus FCBP-0064                                                               0
# Pseudomonas aeruginosa MTCC 424                                                            0
# Escherichia coli nan                                                                       0
# Sphingomonas paucimobilis nan                                                              0
# Staphylococcus haemolyticus nan                                                            0
#
#                                               ...  \
# Klebsiella pneumoniae nan                     ...
# Actinomyces naeslundii nan                    ...
# Hafnia alvei nan                              ...
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)  ...
# Streptococcus mutans MTCC 497                 ...
# ...                                           ...
# Aspergillus flavus FCBP-0064                  ...
# Pseudomonas aeruginosa MTCC 424               ...
# Escherichia coli nan                          ...
# Sphingomonas paucimobilis nan                 ...
# Staphylococcus haemolyticus nan               ...
#
#                                               Aliphatic amidase regulator  \
# Klebsiella pneumoniae nan                                               0
# Actinomyces naeslundii nan                                              0
# Hafnia alvei nan                                                        0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                            0
# Streptococcus mutans MTCC 497                                           0
# ...                                                                   ...
# Aspergillus flavus FCBP-0064                                            0
# Pseudomonas aeruginosa MTCC 424                                         1
# Escherichia coli nan                                                    0
# Sphingomonas paucimobilis nan                                           0
# Staphylococcus haemolyticus nan                                         0
#
#                                               ndhL  \
# Klebsiella pneumoniae nan                        0
# Actinomyces naeslundii nan                       0
# Hafnia alvei nan                                 0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)     0
# Streptococcus mutans MTCC 497                    0
# ...                                            ...
# Aspergillus flavus FCBP-0064                     0
# Pseudomonas aeruginosa MTCC 424                  0
# Escherichia coli nan                             0
# Sphingomonas paucimobilis nan                    0
# Staphylococcus haemolyticus nan                  0
#
#                                               subunit of the ubiquinol-cytochrome c reductase complex, putative  \
# Klebsiella pneumoniae nan                                                                     0
# Actinomyces naeslundii nan                                                                    0
# Hafnia alvei nan                                                                              0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                                  0
# Streptococcus mutans MTCC 497                                                                 0
# ...                                                                                         ...
# Aspergillus flavus FCBP-0064                                                                  0
# Pseudomonas aeruginosa MTCC 424                                                               0
# Escherichia coli nan                                                                          0
# Sphingomonas paucimobilis nan                                                                 0
# Staphylococcus haemolyticus nan                                                               0
#
#                                               Cu-dependent DNA-binding protein, putative  \
# Klebsiella pneumoniae nan                                                              0
# Actinomyces naeslundii nan                                                             0
# Hafnia alvei nan                                                                       0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                           0
# Streptococcus mutans MTCC 497                                                          0
# ...                                                                                  ...
# Aspergillus flavus FCBP-0064                                                           0
# Pseudomonas aeruginosa MTCC 424                                                        0
# Escherichia coli nan                                                                   0
# Sphingomonas paucimobilis nan                                                          0
# Staphylococcus haemolyticus nan                                                        0
#
#                                               YbbN  rapD  \
# Klebsiella pneumoniae nan                        0     0
# Actinomyces naeslundii nan                       0     0
# Hafnia alvei nan                                 0     0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)     0     0
# Streptococcus mutans MTCC 497                    0     0
# ...                                            ...   ...
# Aspergillus flavus FCBP-0064                     0     0
# Pseudomonas aeruginosa MTCC 424                  0     0
# Escherichia coli nan                             0     0
# Sphingomonas paucimobilis nan                    0     0
# Staphylococcus haemolyticus nan                  0     0
#
#                                               carbohydrate phosphorylase  \
# Klebsiella pneumoniae nan                                              0
# Actinomyces naeslundii nan                                             0
# Hafnia alvei nan                                                       0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                           0
# Streptococcus mutans MTCC 497                                          0
# ...                                                                  ...
# Aspergillus flavus FCBP-0064                                           0
# Pseudomonas aeruginosa MTCC 424                                        0
# Escherichia coli nan                                                   0
# Sphingomonas paucimobilis nan                                          0
# Staphylococcus haemolyticus nan                                        0
#
#                                               multidrug and toxin extrusion protein  \
# Klebsiella pneumoniae nan                                                         0
# Actinomyces naeslundii nan                                                        0
# Hafnia alvei nan                                                                  0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                      0
# Streptococcus mutans MTCC 497                                                     0
# ...                                                                             ...
# Aspergillus flavus FCBP-0064                                                      0
# Pseudomonas aeruginosa MTCC 424                                                   0
# Escherichia coli nan                                                              0
# Sphingomonas paucimobilis nan                                                     0
# Staphylococcus haemolyticus nan                                                   0
#
#                                               RNA-binding, CRM domain protein  \
# Klebsiella pneumoniae nan                                                   0
# Actinomyces naeslundii nan                                                  0
# Hafnia alvei nan                                                            0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)                                0
# Streptococcus mutans MTCC 497                                               0
# ...                                                                       ...
# Aspergillus flavus FCBP-0064                                                0
# Pseudomonas aeruginosa MTCC 424                                             0
# Escherichia coli nan                                                        0
# Sphingomonas paucimobilis nan                                               0
# Staphylococcus haemolyticus nan                                             0
#
#                                               YoyE
# Klebsiella pneumoniae nan                        0
# Actinomyces naeslundii nan                       0
# Hafnia alvei nan                                 0
# Streptococcus pyogenes MTCC 1924 (NCTC 3359)     0
# Streptococcus mutans MTCC 497                    0
# ...                                            ...
# Aspergillus flavus FCBP-0064                     0
# Pseudomonas aeruginosa MTCC 424                  0
# Escherichia coli nan                             0
# Sphingomonas paucimobilis nan                    0
# Staphylococcus haemolyticus nan                  0
#
# [235 rows x 115627 columns]

# %%
bacteria_codes_1 = pd.read_excel("/content/drive/MyDrive/AgNPs/genes stuff/bacteriai_list_402.xlsx", index_col=0)
bacteria_codes_1
bacteria_codes = bacteria_codes_1
bacteria_codes
# Out:
#                             bacteria          strain
# 0    Acidovorax avenae subsp. avenae             NaN
# 1            Acinetobacter baumannii             NaN
# 2            Acinetobacter baumannii         AIIMS 7
# 3            Acinetobacter baumannii  ATCC -BAA 1605
# 4            Acinetobacter baumannii      ATCC 19606
# ..                               ...             ...
# 398              Verticillium dahlia        MW830379
# 399                  Vibrio cholerae             NaN
# 400          Vibrio parahaemolyticus             NaN
# 401                Vibrio vulnificus       MTCC 1146
# 402            Williamsia serinedens            SL-1
#
# [403 rows x 2 columns]

# %%
bacteria_codes_1
# Out:
#                             bacteria          strain
# 0    Acidovorax avenae subsp. avenae             NaN
# 1            Acinetobacter baumannii             NaN
# 2            Acinetobacter baumannii         AIIMS 7
# 3            Acinetobacter baumannii  ATCC -BAA 1605
# 4            Acinetobacter baumannii      ATCC 19606
# ..                               ...             ...
# 398              Verticillium dahlia        MW830379
# 399                  Vibrio cholerae             NaN
# 400          Vibrio parahaemolyticus             NaN
# 401                Vibrio vulnificus       MTCC 1146
# 402            Williamsia serinedens            SL-1
#
# [403 rows x 2 columns]

# %%
import os
import pandas as pd
import requests
from collections import defaultdict
from tqdm import tqdm
import difflib

# Load the uploaded bacteria list
#bacteria_codes = pd.read_csv("/content/drive/MyDrive/AgNPs/genes stuff/bacteria_list.csv")
bacteria_strains = [f"{row['bacteria']} {row['strain']}" for _, row in bacteria_codes.iterrows()]

# Step 1: Get all KEGG organism names and codes
response = requests.get("https://rest.kegg.jp/list/organism")
organism_data = [line.split("\t") for line in response.text.strip().split("\n")]
name_to_code = {org[2]: org[1] for org in organism_data}
all_kegg_names = list(name_to_code.keys())

# Step 2: Map bacteria + strain to KEGG organism codes with fuzzy matching
mapped_bacteria = {}
for strain in set(bacteria_strains):
    match = difflib.get_close_matches(strain, all_kegg_names, n=1, cutoff=0.7)
    if match:
        mapped_bacteria[strain] = name_to_code[match[0]]

# KEGG KO Mapping
ko_presence = defaultdict(set)
all_kos = set()
for name, code in tqdm(mapped_bacteria.items(), desc="Fetching KO data"):
    url = f"https://rest.kegg.jp/link/ko/{code}"
    response = requests.get(url)
    if response.status_code == 200:
        lines = response.text.strip().split("\n")
        for line in lines:
            gene_entry, ko_entry = line.split("\t")
            ko = ko_entry.split(":")[1]
            ko_presence[name].add(ko)
            all_kos.add(ko)

ko_matrix = pd.DataFrame(0, index=mapped_bacteria.keys(), columns=list(all_kos))
for name, kos in ko_presence.items():
    ko_matrix.loc[name, list(kos)] = 1
ko_matrix_path = "kegg_ko_matrix.csv"
ko_matrix.to_csv(ko_matrix_path)

# KEGG Pathway Mapping

pathway_presence = defaultdict(set)
all_pathways = set()
for name, code in tqdm(mapped_bacteria.items(), desc="Fetching Pathway data"):
    url = f"https://rest.kegg.jp/link/pathway/{code}"
    response = requests.get(url)
    if response.status_code == 200:
        lines = response.text.strip().split("\n")
        for line in lines:
            _, pathway_entry = line.split("\t")
            pathway = pathway_entry.split(":")[1]
            pathway_presence[name].add(pathway)
            all_pathways.add(pathway)

pathway_matrix = pd.DataFrame(0, index=mapped_bacteria.keys(), columns=list(all_pathways))
for name, pathways in pathway_presence.items():
    pathway_matrix.loc[name, list(pathways)] = 1
pathway_matrix_path = "kegg_pathway_matrix.csv"
pathway_matrix.to_csv(pathway_matrix_path)
# Out:
# Fetching KO data: 100%|██████████| 369/369 [04:20<00:00,  1.42it/s]
# Fetching Pathway data: 100%|██████████| 369/369 [05:11<00:00,  1.19it/s]

# %%
ko_matrix
# Out:
#                                                     K13212  K25031  K02495  \
# Staphylococcus epidermidis ATCC 36983                    0       1       0
# Staphylococcus aureus ATCC 43300                         0       1       0
# Enterobacter cloacae nan                                 0       0       1
# Staphylococcus epidermidis ATCC 12228                    0       1       0
# Klebsiella pneumoniae NCTC 9633                          0       0       1
# ...                                                    ...     ...     ...
# Salmonella enterica subsp. enterica serovar Typ...       0       0       1
# Aspergillus flavus MT550030                              0       0       0
# Klebsiella pneumoniae ATCC 13883                         0       0       1
# Listeria monocytogenes ATCC 51772                        0       1       1
# Escherichia coli ATCC 11775                              0       0       1
#
#                                                     K11773  K11557  K12479  \
# Staphylococcus epidermidis ATCC 36983                    0       0       0
# Staphylococcus aureus ATCC 43300                         0       0       0
# Enterobacter cloacae nan                                 0       0       0
# Staphylococcus epidermidis ATCC 12228                    0       0       0
# Klebsiella pneumoniae NCTC 9633                          0       0       0
# ...                                                    ...     ...     ...
# Salmonella enterica subsp. enterica serovar Typ...       0       0       0
# Aspergillus flavus MT550030                              0       1       1
# Klebsiella pneumoniae ATCC 13883                         0       0       0
# Listeria monocytogenes ATCC 51772                        0       0       0
# Escherichia coli ATCC 11775                              0       0       0
#
#                                                     K22710  K14429  K11443  \
# Staphylococcus epidermidis ATCC 36983                    0       0       0
# Staphylococcus aureus ATCC 43300                         0       0       0
# Enterobacter cloacae nan                                 0       0       0
# Staphylococcus epidermidis ATCC 12228                    0       0       0
# Klebsiella pneumoniae NCTC 9633                          0       0       0
# ...                                                    ...     ...     ...
# Salmonella enterica subsp. enterica serovar Typ...       0       0       0
# Aspergillus flavus MT550030                              0       1       0
# Klebsiella pneumoniae ATCC 13883                         0       0       0
# Listeria monocytogenes ATCC 51772                        0       0       0
# Escherichia coli ATCC 11775                              0       0       0
#
#                                                     K03131  ...  K22510  \
# Staphylococcus epidermidis ATCC 36983                    0  ...       0
# Staphylococcus aureus ATCC 43300                         0  ...       0
# Enterobacter cloacae nan                                 0  ...       0
# Staphylococcus epidermidis ATCC 12228                    0  ...       0
# Klebsiella pneumoniae NCTC 9633                          0  ...       0
# ...                                                    ...  ...     ...
# Salmonella enterica subsp. enterica serovar Typ...       0  ...       1
# Aspergillus flavus MT550030                              1  ...       0
# Klebsiella pneumoniae ATCC 13883                         0  ...       0
# Listeria monocytogenes ATCC 51772                        0  ...       0
# Escherichia coli ATCC 11775                              0  ...       0
#
#                                                     K07097  K11038  K08741  \
# Staphylococcus epidermidis ATCC 36983                    0       0       0
# Staphylococcus aureus ATCC 43300                         0       1       0
# Enterobacter cloacae nan                                 0       0       0
# Staphylococcus epidermidis ATCC 12228                    0       0       0
# Klebsiella pneumoniae NCTC 9633                          0       0       0
# ...                                                    ...     ...     ...
# Salmonella enterica subsp. enterica serovar Typ...       0       0       0
# Aspergillus flavus MT550030                              0       0       0
# Klebsiella pneumoniae ATCC 13883                         0       0       0
# Listeria monocytogenes ATCC 51772                        0       0       0
# Escherichia coli ATCC 11775                              0       0       0
#
#                                                     K14753  K15122  K20297  \
# Staphylococcus epidermidis ATCC 36983                    0       0       0
# Staphylococcus aureus ATCC 43300                         0       0       0
# Enterobacter cloacae nan                                 0       0       0
# Staphylococcus epidermidis ATCC 12228                    0       0       0
# Klebsiella pneumoniae NCTC 9633                          0       0       0
# ...                                                    ...     ...     ...
# Salmonella enterica subsp. enterica serovar Typ...       0       0       0
# Aspergillus flavus MT550030                              1       0       0
# Klebsiella pneumoniae ATCC 13883                         0       0       0
# Listeria monocytogenes ATCC 51772                        0       0       0
# Escherichia coli ATCC 11775                              0       0       0
#
#                                                     K12232  K06653  K07184
# Staphylococcus epidermidis ATCC 36983                    0       0       0
# Staphylococcus aureus ATCC 43300                         0       0       0
# Enterobacter cloacae nan                                 0       0       1
# Staphylococcus epidermidis ATCC 12228                    0       0       0
# Klebsiella pneumoniae NCTC 9633                          0       0       1
# ...                                                    ...     ...     ...
# Salmonella enterica subsp. enterica serovar Typ...       0       0       1
# Aspergillus flavus MT550030                              0       1       0
# Klebsiella pneumoniae ATCC 13883                         0       0       1
# Listeria monocytogenes ATCC 51772                        0       0       0
# Escherichia coli ATCC 11775                              0       0       1
#
# [369 rows x 11273 columns]
